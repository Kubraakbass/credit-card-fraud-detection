# %% [markdown]
# # Credit Card Fraud Detection 💳
#
# Bu projede kredi kartı işlemlerindeki dolandırıcılık işlemlerini
# makine öğrenmesi kullanarak tespit etmeyi amaçlıyoruz.
#
# ## Kullanılan Teknolojiler
# - Python
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - Imbalanced-learn
#
# ## Modeller
# - Logistic Regression
# - Random Forest
# - XGBoost

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    roc_auc_score
)

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("creditcard.csv")

# %%
os.getcwd()import pandas as pd

df = pd.read_csv(r"C:\Users\HP\Downloads\creditcard.csv")
df.head()
# Out:
# 'C:\\Users\\HP'

# %%
df = pd.read_csv("creditcard.csv")

df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
df["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df["Class"].value_counts(normalize=True) * 100
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt

df["Class"].value_counts().plot(kind="bar")

plt.title("Fraud vs Normal Transactions")
plt.xlabel("Class")
plt.ylabel("Count")

plt.show()

# %%
from sklearn.model_selection import train_test_split

X = df.drop("Class", axis=1)
y = df["Class"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(X_train_res, y_train_res)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56864
#            1       0.11      0.90      0.20        98
#
#     accuracy                           0.99     56962
#    macro avg       0.56      0.94      0.60     56962
# weighted avg       1.00      0.99      0.99     56962

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, fmt="d")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
from sklearn.metrics import roc_auc_score

y_prob = model.predict_proba(X_test)[:, 1]

print("ROC-AUC:", roc_auc_score(y_test, y_prob))
# Out:
# ROC-AUC: 0.9756056878998082

# %%
import pandas as pd

feat = pd.Series(model.coef_[0], index=X.columns)
feat.sort_values().plot(kind="barh")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    n_estimators=100,
    class_weight="balanced",
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\hp\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\hp\anaconda3\lib\site-packages (from xgboost) (1.13.1)

# %%
from xgboost import XGBClassifier

model = XGBClassifier(
    scale_pos_weight=99,
    eval_metric="logloss"
)

model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\hp\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\hp\anaconda3\lib\site-packages (from xgboost) (1.13.1)

# %%
from xgboost import XGBClassifier
print("XGBoost OK")
# Out:
# XGBoost OK

# %%
from xgboost import XGBClassifier

model = XGBClassifier(
    n_estimators=200,
    max_depth=4,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    scale_pos_weight=99,  # imbalance için kritik
    eval_metric="logloss",
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:, 1]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.83      0.86      0.84        98
#
#     accuracy                           1.00     56962
#    macro avg       0.92      0.93      0.92     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, fmt="d")
plt.title("XGBoost Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
from sklearn.metrics import roc_auc_score

print("ROC-AUC:", roc_auc_score(y_test, y_prob))
# Out:
# ROC-AUC: 0.9799559349626176

# %%
import numpy as np

y_pred_custom = (y_prob > 0.3).astype(int)

print(classification_report(y_test, y_pred_custom))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.74      0.87      0.80        98
#
#     accuracy                           1.00     56962
#    macro avg       0.87      0.93      0.90     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(y_test, y_prob)

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt

plot_importance(model)
plt.show()

# %%
y_prob = model.predict_proba(X_test)[:, 1]

# %%
import numpy as np
from sklearn.metrics import classification_report

thresholds = np.arange(0.1, 0.9, 0.05)

for t in thresholds:
    y_pred = (y_prob >= t).astype(int)
    
    print(f"\n🔹 Threshold: {t:.2f}")
    print(classification_report(y_test, y_pred, digits=3))
# Out:
# 🔹 Threshold: 0.10
#               precision    recall  f1-score   support
#
#            0      1.000     0.999     0.999     56864
#            1      0.527     0.888     0.662        98
#
#     accuracy                          0.998     56962
#    macro avg      0.764     0.943     0.830     56962
# weighted avg      0.999     0.998     0.999     56962
#
#
# 🔹 Threshold: 0.15
#               precision    recall  f1-score   support
#
#            0      1.000     0.999     0.999     56864
#            1      0.590     0.867     0.702        98
#
#     accuracy                          0.999     56962
#    macro avg      0.795     0.933     0.851     56962
# weighted avg      0.999     0.999     0.999     56962
#
#
# 🔹 Threshold: 0.20
#               precision    recall  f1-score   support
#
#            0      1.000     0.999     0.999     56864
#            1      0.659     0.867     0.749        98
#
#     accuracy                          0.999     56962
#    macro avg      0.829     0.933     0.874     56962
# weighted avg      0.999     0.999     0.999     56962
#
#
# 🔹 Threshold: 0.25
#               precision    recall  f1-score   support
#
#            0      1.000     0.999     1.000     56864
#            1      0.697     0.867     0.773        98
#
#     accuracy                          0.999     56962
#    macro avg      0.848     0.933     0.886     56962
# weighted avg      0.999     0.999     0.999     56962
#
#
# 🔹 Threshold: 0.30
#               precision    recall  f1-score   support
#
#            0      1.000     0.999     1.000     56864
#            1      0.739     0.867     0.798        98
#
#     accuracy                          0.999     56962
#    macro avg      0.869     0.933     0.899     56962
# weighted avg      0.999     0.999     0.999     56962
#
#
# 🔹 Threshold: 0.35
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000     56864
#            1      0.771     0.857     0.812        98
#
#     accuracy                          0.999     56962
#    macro avg      0.885     0.928     0.906     56962
# weighted avg      0.999     0.999     0.999     56962
#
#
# 🔹 Threshold: 0.40
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000     56864
#            1      0.785     0.857     0.820        98
#
#     accuracy                          0.999     56962
#    macro avg      0.892     0.928     0.910     56962
# weighted avg      0.999     0.999     0.999     56962
#
#
# 🔹 Threshold: 0.45
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000     56864
#            1      0.800     0.857     0.828        98
#
#     accuracy                          0.999     56962
#    macro avg      0.900     0.928     0.914     56962
# weighted avg      0.999     0.999     0.999     56962
#
#
# 🔹 Threshold: 0.50
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000     56864
#            1      0.832     0.857     0.844        98
#
#     accuracy                          0.999     56962
#    macro avg      0.916     0.928     0.922     56962
# weighted avg      0.999     0.999     0.999     56962
#
#
# 🔹 Threshold: 0.55
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000     56864
#            1      0.857     0.857     0.857        98
#
#     accuracy                          1.000     56962
#    macro avg      0.928     0.928     0.928     56962
# weighted avg      1.000     1.000     1.000     56962
#
#
# 🔹 Threshold: 0.60
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000     56864
#            1      0.865     0.847     0.856        98
#
#     accuracy                          1.000     56962
#    macro avg      0.932     0.923     0.928     56962
# weighted avg      1.000     1.000     1.000     56962
#
#
# 🔹 Threshold: 0.65
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000     56864
#            1      0.865     0.847     0.856        98
#
#     accuracy                          1.000     56962
#    macro avg      0.932     0.923     0.928     56962
# weighted avg      1.000     1.000     1.000     56962
#
#
# 🔹 Threshold: 0.70
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000     56864
#            1      0.872     0.837     0.854        98
#
#     accuracy                          1.000     56962
#    macro avg      0.936     0.918     0.927     56962
# weighted avg      0.999     1.000     1.000     56962
#
#
# 🔹 Threshold: 0.75
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000     56864
#            1      0.871     0.827     0.848        98
#
#     accuracy                          0.999     56962
#    macro avg      0.935     0.913     0.924     56962
# weighted avg      0.999     0.999     0.999     56962
#
#
# 🔹 Threshold: 0.80
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000     56864
#            1      0.871     0.827     0.848        98
#
#     accuracy                          0.999     56962
#    macro avg      0.935     0.913     0.924     56962
# weighted avg      0.999     0.999     0.999     56962
#
#
# 🔹 Threshold: 0.85
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000     56864
#            1      0.878     0.806     0.840        98
#
#     accuracy                          0.999     56962
#    macro avg      0.939     0.903     0.920     56962
# weighted avg      0.999     0.999     0.999     56962

# %%
from sklearn.metrics import f1_score

best_t = 0
best_f1 = 0

for t in np.arange(0.1, 0.9, 0.01):
    y_pred = (y_prob >= t).astype(int)
    f1 = f1_score(y_test, y_pred)
    
    if f1 > best_f1:
        best_f1 = f1
        best_t = t

print("Best Threshold:", best_t)
print("Best F1 Score:", best_f1)
# Out:
# Best Threshold: 0.6599999999999997
# Best F1 Score: 0.8601036269430051

# %%
from sklearn.metrics import recall_score

best_t = 0
best_recall = 0

for t in np.arange(0.1, 0.9, 0.01):
    y_pred = (y_prob >= t).astype(int)
    rec = recall_score(y_test, y_pred)
    
    if rec > best_recall:
        best_recall = rec
        best_t = t

print("Best Recall Threshold:", best_t)
print("Best Recall:", best_recall)
# Out:
# Best Recall Threshold: 0.1
# Best Recall: 0.8877551020408163

# %%
from sklearn.metrics import precision_score, recall_score

for t in np.arange(0.1, 0.9, 0.01):
    y_pred = (y_prob >= t).astype(int)
    
    p = precision_score(y_test, y_pred)
    r = recall_score(y_test, y_pred)
    
    if p >= 0.70:
        print(f"Threshold: {t:.2f} | Precision: {p:.3f} | Recall: {r:.3f}")
# Out:
# Threshold: 0.26 | Precision: 0.702 | Recall: 0.867
# Threshold: 0.27 | Precision: 0.714 | Recall: 0.867
# Threshold: 0.28 | Precision: 0.733 | Recall: 0.867
# Threshold: 0.29 | Precision: 0.739 | Recall: 0.867
# Threshold: 0.30 | Precision: 0.739 | Recall: 0.867
# Threshold: 0.31 | Precision: 0.746 | Recall: 0.867
# Threshold: 0.32 | Precision: 0.752 | Recall: 0.867
# Threshold: 0.33 | Precision: 0.757 | Recall: 0.857
# Threshold: 0.34 | Precision: 0.764 | Recall: 0.857
# Threshold: 0.35 | Precision: 0.771 | Recall: 0.857
# Threshold: 0.36 | Precision: 0.771 | Recall: 0.857
# Threshold: 0.37 | Precision: 0.778 | Recall: 0.857
# Threshold: 0.38 | Precision: 0.785 | Recall: 0.857
# Threshold: 0.39 | Precision: 0.785 | Recall: 0.857
# Threshold: 0.40 | Precision: 0.785 | Recall: 0.857
# Threshold: 0.41 | Precision: 0.792 | Recall: 0.857
# Threshold: 0.42 | Precision: 0.792 | Recall: 0.857
# Threshold: 0.43 | Precision: 0.800 | Recall: 0.857
# Threshold: 0.44 | Precision: 0.800 | Recall: 0.857
# Threshold: 0.45 | Precision: 0.800 | Recall: 0.857
# Threshold: 0.46 | Precision: 0.800 | Recall: 0.857
# Threshold: 0.47 | Precision: 0.816 | Recall: 0.857
# Threshold: 0.48 | Precision: 0.824 | Recall: 0.857
# Threshold: 0.49 | Precision: 0.824 | Recall: 0.857
# Threshold: 0.50 | Precision: 0.832 | Recall: 0.857
# Threshold: 0.51 | Precision: 0.832 | Recall: 0.857
# Threshold: 0.52 | Precision: 0.840 | Recall: 0.857
# Threshold: 0.53 | Precision: 0.848 | Recall: 0.857
# Threshold: 0.54 | Precision: 0.857 | Recall: 0.857
# Threshold: 0.55 | Precision: 0.857 | Recall: 0.857
# Threshold: 0.56 | Precision: 0.856 | Recall: 0.847
# Threshold: 0.57 | Precision: 0.856 | Recall: 0.847
# Threshold: 0.58 | Precision: 0.856 | Recall: 0.847
# Threshold: 0.59 | Precision: 0.856 | Recall: 0.847
# Threshold: 0.60 | Precision: 0.865 | Recall: 0.847
# Threshold: 0.61 | Precision: 0.865 | Recall: 0.847
# Threshold: 0.62 | Precision: 0.865 | Recall: 0.847
# Threshold: 0.63 | Precision: 0.865 | Recall: 0.847
# Threshold: 0.64 | Precision: 0.865 | Recall: 0.847
# Threshold: 0.65 | Precision: 0.865 | Recall: 0.847
# Threshold: 0.66 | Precision: 0.874 | Recall: 0.847
# Threshold: 0.67 | Precision: 0.872 | Recall: 0.837
# Threshold: 0.68 | Precision: 0.872 | Recall: 0.837
# Threshold: 0.69 | Precision: 0.872 | Recall: 0.837
# Threshold: 0.70 | Precision: 0.872 | Recall: 0.837
# Threshold: 0.71 | Precision: 0.872 | Recall: 0.837
# Threshold: 0.72 | Precision: 0.872 | Recall: 0.837
# Threshold: 0.73 | Precision: 0.872 | Recall: 0.837
# Threshold: 0.74 | Precision: 0.872 | Recall: 0.837
# Threshold: 0.75 | Precision: 0.871 | Recall: 0.827
# Threshold: 0.76 | Precision: 0.871 | Recall: 0.827
# Threshold: 0.77 | Precision: 0.871 | Recall: 0.827
# Threshold: 0.78 | Precision: 0.871 | Recall: 0.827
# Threshold: 0.79 | Precision: 0.871 | Recall: 0.827
# Threshold: 0.80 | Precision: 0.871 | Recall: 0.827
# Threshold: 0.81 | Precision: 0.871 | Recall: 0.827
# Threshold: 0.82 | Precision: 0.868 | Recall: 0.806
# Threshold: 0.83 | Precision: 0.878 | Recall: 0.806
# Threshold: 0.84 | Precision: 0.878 | Recall: 0.806
# Threshold: 0.85 | Precision: 0.878 | Recall: 0.806
# Threshold: 0.86 | Precision: 0.888 | Recall: 0.806
# Threshold: 0.87 | Precision: 0.898 | Recall: 0.806
# Threshold: 0.88 | Precision: 0.898 | Recall: 0.806
# Threshold: 0.89 | Precision: 0.908 | Recall: 0.806

# %%
final_pred = (y_prob >= best_t).astype(int)

# %%
print(classification_report(y_test, final_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.53      0.89      0.66        98
#
#     accuracy                           1.00     56962
#    macro avg       0.76      0.94      0.83     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

precision, recall, thresholds = precision_recall_curve(y_test, y_prob)

plt.figure(figsize=(8,5))
plt.plot(recall, precision)

plt.title("Precision–Recall Curve")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.grid()
plt.show()

# %%
from sklearn.metrics import f1_score
import numpy as np
import matplotlib.pyplot as plt

thresholds = np.arange(0.1, 0.9, 0.01)
f1_scores = []

for t in thresholds:
    y_pred = (y_prob >= t).astype(int)
    f1_scores.append(f1_score(y_test, y_pred))

plt.figure(figsize=(8,5))
plt.plot(thresholds, f1_scores)

plt.title("Threshold vs F1 Score")
plt.xlabel("Threshold")
plt.ylabel("F1 Score")
plt.grid()
plt.show()

# %%
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
best_f1 = f1_scores[best_idx]

print("Best Threshold:", best_threshold)
print("Best F1:", best_f1)
# Out:
# Best Threshold: 0.6599999999999997
# Best F1: 0.8601036269430051

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred_best = (y_prob >= best_threshold).astype(int)

cm = confusion_matrix(y_test, y_pred_best)

sns.heatmap(cm, annot=True, fmt="d")
plt.title("Confusion Matrix (Best Threshold)")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
